# %%
import matplotlib.pyplot as plt; import numpy as np; plt.rcParams['figure.figsize']= [15,6]
t = np.linspace(0,0.1,200)

bh1 = np.cos(np.pi*(100*t+1/6));
bh2 = np.cos(np.pi*(100*t+1/6));

plt.plot(t,bh1, 'orange')
plt.plot(t,bh2, 'blue')

# %%
plt.plot(np.convolve(bh1,bh2), linewidth=3)
plt.plot(194,94.25783741017165 , marker="o", markersize=5, markerfacecolor="red")

# %%
max(np.convolve(bh1,bh2))
# Out:
# 94.25783741017165

# %%
print(np.convolve(bh1,bh2))
# Out:
# [  0.75         1.34519547   1.76011835   1.97743556   1.98855454
#    1.79391625   1.40296633   0.83380565   0.11253182  -0.72770696
#   -1.64791457  -2.60466695  -3.5517029   -4.44163341  -5.22771301
#   -5.86561458  -6.31514795  -6.54186449  -6.51849258  -6.22615387
#   -5.65531685  -4.80645174  -3.69036021  -2.32816316  -0.75094054
#    1.00097211   2.87901431   4.82773254   6.78637685   8.69071733
#   10.47502742  12.07417538  13.42576028  14.47222683  15.16289219
#   15.45581976  15.31947796  14.73412745  13.69288735  12.20243958
#   10.28334057   7.96992066   5.30976355   2.36277038  -0.80017438
#   -4.09890597  -7.44601039 -10.74913205 -13.91349735 -16.84458566
#  -19.45087363 -21.64657463 -23.35429382 -24.5075197  -25.0528762
#  -24.95206435 -24.18343001 -22.74310335 -20.64566677 -17.92432049
#  -14.63052851 -10.83314201  -6.61701196  -2.08111745   2.66374981
#    7.49769073  12.29472786  16.92608161  21.26360874  25.18331164
# ...
