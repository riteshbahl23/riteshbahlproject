# %%
import matplotlib.pyplot as plt; import numpy as np; plt.rcParams['figure.figsize']= [15,6]

t = np.linspace(0,0.1,205)

h2 = np.cos(np.pi*(100*t+1/6));
h1 = np.cos(np.pi*(100*t+1/6));
plt.plot(t,h1,linewidth=3 ) # plotting h(t)
plt.plot(t,h2,linewidth=3 ) # plotting h(t)

# %%
plt.plot(np.convolve(h1,h2), linewidth=3)
plt.plot(197, 94.45783741017176, marker="o", markersize=8, markerfacecolor="orange")

# %%
plt.plot(194, 94.25783741017165, marker="o", markersize=5, markerfacecolor="orange")
